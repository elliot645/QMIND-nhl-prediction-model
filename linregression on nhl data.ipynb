# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('mlData.csv')
X = data.iloc[:, 1:-1].values
y = data.iloc[:, -1].values
data.tail(100)
# Out:
#            gameId  avgGoalDif  avgXGoalDif  avgHF  winStreak  avgPPG  \
# 15757  2022020733        -1.6      -0.2244    5.0        0.0    -0.8
# 15758  2022020734         0.6       1.0290    0.6        1.0     0.0
# 15759  2022020735         0.4      -0.3804   -1.8        1.0    -0.4
# 15760  2022020736        -1.0      -0.7166   -4.6       -1.0    -0.4
# 15761  2022020737        -0.2      -1.4142   -2.6       -2.0     0.0
# ...           ...         ...          ...    ...        ...     ...
# 15852  2022020828         2.0       0.6222    9.8        3.0     0.8
# 15853  2022020829        -1.4      -2.4604   -1.2        0.0    -0.8
# 15854  2022020830        -2.0      -1.6284    1.2       -1.0    -0.8
# 15855  2022020831         1.6      -0.4206  -14.6        0.0     0.8
# 15856  2022020990        -0.4      -1.2478  -13.4        2.0     0.0
#
#        daysSinceLast  goalsFor
# 15757            1.0       3.0
# 15758            0.0       2.0
# 15759            0.0      -1.0
# 15760           -1.0       2.0
# 15761            0.0       1.0
# ...              ...       ...
# 15852            1.0       3.0
# 15853            1.0      -3.0
# 15854           -1.0       1.0
# 15855            0.0      -3.0
# 15856            1.0      -4.0
#
# [100 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.neural_network import MLPRegressor
#from MLPRegressor import LinearRegression

regressor = MLPRegressor(activation='logistic', )
regressor.fit(X_train, y_train)

#test our model
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred})
x = df.index.values.tolist()
# df.head(80)
df.corr()
#pd.options.display.max_rows = 100
# Out:
#                   Real Values  Predicted Values
# Real Values          1.000000          0.104738
# Predicted Values     0.104738          1.000000

# %%
plt.scatter(x,y_pred)
plt.scatter(x,y_test)

# %%
# Out:
#                   Real Values  Predicted Values
# Real Values          1.000000          0.125075
# Predicted Values     0.125075          1.000000
